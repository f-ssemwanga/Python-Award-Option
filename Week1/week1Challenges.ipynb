# %% [markdown]
# ### Week 1 Challenges
#
# **Time:** the second half of the lesson, plus homework
#
# The placement check at the top of `Week1-Python-intro.ipynb` told you which lane you are in this week.
#
# - **Core:** do Challenges 1 to 4. Skip the Fast Track section.
# - **Fast Track:** skip straight to the Fast Track section. Do not do both.
#
# #### How this notebook works
#
# - Each challenge has a code cell for your answer. Add more cells with **+ Code** if you need them.
# - Stuck? Each challenge has **hints hidden underneath it**. Click a hint to open it. Try for five minutes before you do, because the struggle is where the learning happens. Hint 1 gives you the steps in plain English. Hint 2 gives away more.
# - Fast Track challenges have a **check cell**. Run it after your answer. If it prints `All checks passed`, you are done.
# - The **model solutions** are locked at the bottom of this notebook. Your teacher gives out the passphrase after the lesson.

# %% [markdown]
# ## Core challenges
#
# You do not need functions for any of these. Everything you need is in the intro notebook: variables, `input()`, arithmetic and f-strings.

# %% [markdown]
# ### Core 1: Temperature converter
#
# Ask the user for a temperature in Celsius and print it in Fahrenheit. Then ask for one in Fahrenheit and print it in Celsius.
#
# - `F = C * 9 / 5 + 32`
# - `C = (F - 32) * 5 / 9`
# - One decimal place, in a full sentence
#
# **It should look like this** (the user typed `21` and `70`):
#
# ```text
# Enter a temperature in Celsius: 21
# 21.0 C is 69.8 F
# Enter a temperature in Fahrenheit: 70
# 70.0 F is 21.1 C
# ```
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# celsius    <- ask the user, and turn the answer into a float
# fahrenheit <- celsius * 9 / 5 + 32
# print a sentence showing both, one decimal place each
#
# then the same again, the other way round
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# `input()` always gives you text. Wrap it in `float()` straight away:
#
# ```python
# celsius = float(input("Enter a temperature in Celsius: "))
# ```
#
# One decimal place inside an f-string is `{fahrenheit:.1f}`.
#
# </details>

# %%
# Core 1: your code here

# %% [markdown]
# ### Core 2: Weather report
#
# The real Armagh readings for January 2026 are already in the cell below. Add the code that prints this report:
#
# ```text
# Weather report: Armagh, January 2026
#   Mean daily maximum: 7.2 C
#   Mean daily minimum: 2.1 C
#   Temperature range:  5.1 C
#   Rainfall:           140.0 mm
#   Frost days:         9
#   Sunshine:           45.7 hours
# ```
#
# The temperature range is not given to you. Work it out as `tmax - tmin`.
#
# Compare it with Oxford in July from the intro notebook: 140 mm of rain against none at all, and 45.7 hours of sunshine against 353.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# temp_range <- tmax - tmin
# print the title line, with the station and the month in it
# print one line per reading, each one an f-string
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# The first two lines of the report:
#
# ```python
# print(f"Weather report: {station}, {month}")
# print(f"  Mean daily maximum: {tmax:.1f} C")
# ```
#
# The spaces after each label are what line the numbers up. Count them.
#
# </details>

# %%
station = "Armagh"
month = "January 2026"
tmax = 7.2
tmin = 2.1
rain = 140.0
frost_days = 9
sun = 45.7

# Core 2: your code below this line

# %% [markdown]
# ### Core 3: Name details
#
# Ask the user for their full name, then print it in capitals, how many characters it has **not counting spaces**, and the name reversed.
#
# **It should look like this:**
#
# ```text
# Enter your full name: Ada Lovelace
# In capitals: ADA LOVELACE
# Characters, not counting spaces: 11
# Reversed: ecalevoL adA
# ```
#
# Three tools you need:
#
# | Code | Does |
# | --- | --- |
# | `name.upper()` | The name in capitals |
# | `name.replace(" ", "")` | The name with every space removed |
# | `len(something)` | How many characters are in it |
# | `name[::-1]` | The name backwards |
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# full_name <- ask the user
# print full_name in capitals
# no_spaces <- full_name with every " " replaced by ""
# print how long no_spaces is
# print full_name backwards
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# The count is two tools joined together. Remove the spaces first, then count what is left:
#
# ```python
# no_spaces = full_name.replace(" ", "")
# print(f"Characters, not counting spaces: {len(no_spaces)}")
# ```
#
# </details>

# %%
# Core 3: your code here

# %% [markdown]
# ### Core 4: Bill splitter
#
# Three people share a restaurant bill. Ask for the total in pounds, then print what each person pays and how many pence are left over that will not split evenly.
#
# Work in **pence**, not pounds. Turn the total into pence, then use `//` for each share and `%` for what is left over.
#
# **It should look like this:**
#
# ```text
# Enter the bill total in pounds: 100
# Each person pays £33.33
# 1p is left over
# ```
#
# Test it with `19.99` as well. Each person should pay £6.66 with 1p left over. If you get 0p left over, look at Hint 2.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# total       <- ask the user, as a float
# total_pence <- total * 100, rounded to a whole number
# each_pence  <- total_pence // 3
# left_over   <- total_pence % 3
# print each_pence / 100 to two decimal places
# print left_over
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# Use `round()`, not `int()`, to turn pounds into pence:
#
# ```python
# total_pence = round(total * 100)
# ```
#
# Inside the computer `19.99 * 100` is `1998.9999999999998`. `int()` chops off everything after the point and gives 1998, so a penny goes missing without any error. `round()` gives 1999.
#
# </details>

# %%
# Core 4: your code here

# %% [markdown]
# ## Fast Track challenges
#
# Only if you scored 5 out of 5 on the placement check.
#
# You already know variables, input, selection and loops, so none of that is here. This week is about writing functions the way working programmers write them: with **type hints**, a **docstring**, and a value that is **returned** rather than printed.
#
# Here is the shape every function in this section should have:
#
# ```python
# def celsius_to_fahrenheit(celsius: float) -> float:
#     """Convert a temperature from Celsius to Fahrenheit."""
#     return celsius * 9 / 5 + 32
# ```
#
# - `celsius: float` says what type the parameter should be
# - `-> float` says what type comes back
# - The line in triple quotes is the docstring. It says what the function does, in one sentence
#
# None of your functions should call `input()` or `print()`. The check cells test them directly.

# %% [markdown]
# ### Fast Track 1: Functions done properly
#
# `celsius_to_fahrenheit` is written for you below. Add two more in the same shape:
#
# 1. `fahrenheit_to_celsius(fahrenheit)`, which returns the Celsius value
# 2. `temperature_range(tmax, tmin)`, which returns `tmax - tmin`
#
# Then run the check cell.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# copy the three lines of celsius_to_fahrenheit
# change the name, the parameter name and the docstring
# change the return line to (fahrenheit - 32) * 5 / 9
#
# temperature_range takes two parameters, both floats,
# and returns one minus the other
# ```
#
# </details>

# %%
def celsius_to_fahrenheit(celsius: float) -> float:
    """Convert a temperature from Celsius to Fahrenheit."""
    return celsius * 9 / 5 + 32


# Fast Track 1: your two functions below this line

# %%
# Check cell. Run this after your answer. Do not change it.
assert fahrenheit_to_celsius(212) == 100, "212 F should be 100 C"
assert fahrenheit_to_celsius(32) == 0, "32 F should be 0 C"
assert round(temperature_range(7.2, 2.1), 1) == 5.1, "7.2 and 2.1 should give 5.1"
assert fahrenheit_to_celsius.__doc__, "fahrenheit_to_celsius needs a docstring"
assert temperature_range.__doc__, "temperature_range needs a docstring"
assert "return" in fahrenheit_to_celsius.__annotations__, "fahrenheit_to_celsius needs a -> return type"
assert "return" in temperature_range.__annotations__, "temperature_range needs a -> return type"
print("All checks passed")

# %% [markdown]
# ### Fast Track 2: Initials
#
# Write `initials(full_name: str) -> str`, which returns the initials of any name, in capitals, each followed by a full stop.
#
# | Call | Returns |
# | --- | --- |
# | `initials("francis ssemwanga")` | `"F.S."` |
# | `initials("Mary Jane Watson")` | `"M.J.W."` |
# | `initials("  Ada   Lovelace ")` | `"A.L."` |
# | `initials("Cher")` | `"C."` |
#
# The third one is the catch. Real users type extra spaces.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# parts  <- full_name split into words
# result <- empty string
# for each part in parts:
#     add the part's first letter, in capitals, then "."
# return result
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# `full_name.split()` with **nothing** in the brackets splits on any amount of whitespace and ignores spaces at the ends. `split(" ")` does not, and gives you empty strings that crash `part[0]`.
#
# </details>

# %%
# Fast Track 2: your code here

# %%
# Check cell. Run this after your answer. Do not change it.
assert initials("francis ssemwanga") == "F.S.", "two names, lower case"
assert initials("Mary Jane Watson") == "M.J.W.", "three names"
assert initials("  Ada   Lovelace ") == "A.L.", "extra spaces"
assert initials("Cher") == "C.", "one name"
assert initials.__doc__, "initials needs a docstring"
print("All checks passed")

# %% [markdown]
# ### Fast Track 3: Improve someone else's code
#
# The cell below works. Run it and it prints the right answer. It is still bad code.
#
# Rewrite it underneath so that someone reading it in six months understands it straight away. It should have:
#
# - A function name that says what it does, and parameter names that say what they hold
# - Type hints and a docstring
# - An f-string instead of `+` and `str()`, showing the result to one decimal place
# - No variables that are not needed
#
# Then, in the markdown cell below it, write two sentences: which single change made the biggest difference, and why.
#
# Reading and improving code you did not write is most of what programming actually is.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# work out what f actually calculates, and name it after that
# a, b and c are three numbers: name them so that reads naturally
# x and y only exist to be returned: return the sum divided by 3 directly
# the print line: one f-string, with :.1f on the result
# ```
#
# </details>

# %%
def f(a,b,c):
    x=a+b+c
    y=x/3
    return y
print("avg is "+str(f(7.2,15.6,28.2)))

# %%
# Fast Track 3: your improved version here

# %% [markdown]
# *Fast Track 3: your two sentences here. Double click to edit.*

# %% [markdown]
# ### Fast Track 4 (stretch): Calculator
#
# Only if you have finished 1 to 3.
#
# Write `calculate(a: float, b: float, operator: str) -> float | None`. It takes two numbers and one of `"+"`, `"-"`, `"*"`, `"/"`, `"//"` or `"%"`, and returns the answer.
#
# It must **never crash**. If it is asked to divide by zero, or given an operator it does not know, it returns `None`. You have not met `try` and `except` yet, so do it with `if`.
#
# <details>
# <summary><b>Hint 1</b> (click to open)</summary>
#
# ```text
# if operator is "+": return a + b
# ... one branch for each operator ...
#
# before any of the three divisions:
#     if b is 0: return None
#
# if nothing matched: return None
# ```
#
# </details>
#
# <details>
# <summary><b>Hint 2</b> (click to open)</summary>
#
# The zero check has to come **before** the division, not after it. By the time the division runs, it has already crashed.
#
# ```python
# if operator in ("/", "//", "%") and b == 0:
#     return None
# ```
#
# </details>

# %%
# Fast Track 4: your code here

# %%
# Check cell. Run this after your answer. Do not change it.
assert calculate(7, 2, "+") == 9
assert calculate(7, 2, "-") == 5
assert calculate(7, 2, "*") == 14
assert calculate(7, 2, "/") == 3.5
assert calculate(7, 2, "//") == 3
assert calculate(7, 2, "%") == 1
assert calculate(7, 0, "/") is None, "dividing by zero should return None"
assert calculate(7, 0, "%") is None, "modulus by zero should return None"
assert calculate(7, 2, "^") is None, "an unknown operator should return None"
print("All checks passed")

# %% [markdown]
# ## Before you finish, both lanes
#
# **Plenary.** Be ready to show the class one thing you found out today that surprised you. It might be an error message, a result you did not expect, or a hint you needed.
#
# **Exit ticket.** Answer both in the cell below, as a comment or as code.
#
# 1. In one sentence, why does `input()` returning a string matter?
# 2. Write one line that prints the number `7.456` to two decimal places.
#
# **Save your work** with Ctrl and S, then commit and sync it. `Week1/usingGitHub.ipynb` shows you how.
#
# **Next week:** control structures. Making the program decide things and repeat things.

# %%
# 1.

# 2.

# %% [markdown]
# ## Model solutions
#
# Locked until your teacher gives out the passphrase. Run the cell below and type it in when asked. Capitals and extra spaces do not matter.
#
# Use the solutions to compare, not to copy. Put yours and the model side by side and look for one thing in the model you would do differently next time.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
