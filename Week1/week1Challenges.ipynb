# %% [markdown]
# ### Week 1 Challenges
#
# Do **your lane only**. The placement check told you which one.
#
# - Three challenges each. Number 3 is the **extension**: do it if you finish 1 and 2.
# - Stuck? Run the **hint cell** under the challenge. Have a proper go first.
# - Model solutions are locked at the bottom until after the lesson.

# %% [markdown]
# ## Core

# %% [markdown]
# ### Core 1: Temperature converter
#
# Ask for a temperature in Celsius and print it in Fahrenheit, to one decimal place.
#
# `F = C * 9 / 5 + 32`
#
# ```text
# Enter a temperature in Celsius: 21
# 21.0 C is 69.8 F
# ```

# %%
# Hint 1 for Core 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 1: your code here

# %% [markdown]
# ### Core 2: Weather report
#
# **No input this time.** The readings are already stored in variables in the cell below (real figures for Armagh, January 2026). Your job is to **print them as a tidy report** using f-strings.
#
# The only thing you calculate is the temperature range: `tmax - tmin`.
#
# Your output should look exactly like this:
#
# ```text
# Weather report: Armagh, January 2026
#   Mean daily maximum: 7.2 C
#   Mean daily minimum: 2.1 C
#   Temperature range:  5.1 C
#   Rainfall:           140.0 mm
# ```

# %%
# Hint 1 for Core 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
station = "Armagh"
month = "January 2026"
tmax = 7.2
tmin = 2.1
rain = 140.0

# Core 2: your code below this line

# %% [markdown]
# ### Core 3 (extension): Bill splitter
#
# Three people share a bill. Ask for the total in pounds, then print what each person pays and how many pence are left over.
#
# Work in pence: use `//` for each share and `%` for what is left over.
#
# ```text
# Enter the bill total in pounds: 100
# Each person pays £33.33
# 1p is left over
# ```
#
# Then try `19.99`. You should get £6.66 and 1p left over.

# %%
# Hint 1 for Core 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
# Core 3: your code here

# %% [markdown]
# ## Fast Track
#
# Functions the way working programmers write them: one job each, a **docstring** saying what the job is, and the answer **returned**, not printed.
#
# ```python
# def celsius_to_fahrenheit(celsius):
#     """Convert a temperature from Celsius to Fahrenheit."""
#     return celsius * 9 / 5 + 32
# ```
#
# Test each function by printing what it returns for the examples given.

# %% [markdown]
# ### Fast Track 1: Two more functions
#
# Add `fahrenheit_to_celsius(fahrenheit)` and `temperature_range(tmax, tmin)` in the same shape.
#
# | Call | Returns |
# | --- | --- |
# | `fahrenheit_to_celsius(212)` | `100.0` |
# | `temperature_range(7.2, 2.1)` | `5.1` |

# %%
# Hint 1 for Fast Track 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("Y29weSB0aGUgdGhyZWUgbGluZXMgb2YgY2Vsc2l1c190b19mYWhyZW5oZWl0CmNoYW5nZSB0aGUgbmFtZSwgdGhlIHBhcmFtZXRlciBhbmQgdGhlIGRvY3N0cmluZwpyZXR1cm4gKGZhaHJlbmhlaXQgLSAzMikgKiA1IC8gOQoKdG8gdGVzdDogIHByaW50KGZhaHJlbmhlaXRfdG9fY2Vsc2l1cygyMTIpKQ==").decode())

# %%
def celsius_to_fahrenheit(celsius):
    """Convert a temperature from Celsius to Fahrenheit."""
    return celsius * 9 / 5 + 32


# Fast Track 1: your two functions and your tests below this line

# %% [markdown]
# ### Fast Track 2: Initials
#
# Write `initials(full_name)`, returning the initials in capitals, each followed by a full stop.
#
# | Call | Returns |
# | --- | --- |
# | `initials("francis ssemwanga")` | `"F.S."` |
# | `initials("Mary Jane Watson")` | `"M.J.W."` |
# | `initials("  Ada   Lovelace ")` | `"A.L."` |

# %%
# Hint 1 for Fast Track 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Fast Track 2: your code here

# %% [markdown]
# ### Fast Track 3 (extension): Improve someone else's code
#
# The cell below works, but it is bad code. Rewrite it underneath so it is easy to read: a clear function name and parameter names, a docstring, an f-string showing one decimal place, and no pointless variables.
#
# Then write one sentence in the markdown cell: which change made the biggest difference?

# %%
# Hint 1 for Fast Track 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
def f(a,b,c):
    x=a+b+c
    y=x/3
    return y
print("avg is "+str(f(7.2,15.6,28.2)))

# %%
# Fast Track 3: your improved version here

# %% [markdown]
# *Fast Track 3: your sentence here. Double click to edit.*

# %% [markdown]
# ## Before you finish
#
# **Exit ticket.** In the cell below: why does `input()` returning a string matter? One sentence.
#
# Then save with Ctrl and S, and commit and sync (`usingGitHub.ipynb`, Part 5).

# %%
# Exit ticket

# %% [markdown]
# ## Model solutions
#
# Run the cell and type the passphrase your teacher gives you. Compare, do not copy.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

FStk/kKpw1nBZv9anyImAUc8sQBkDTxHfpXS8GsRb35MrpDSaQWlToHw
"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
