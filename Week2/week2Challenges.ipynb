# %% [markdown]
# ### Week 2 Challenges
#
# Do **your lane only**. The placement check told you which one.
#
# - Three challenges each. Number 3 is the **extension**: do it if you finish 1 and 2.
# - Stuck? Run the **hint cell** under the challenge. Have a proper go first.
# - Model solutions are locked at the bottom until after the lesson.

# %% [markdown]
# ## Core

# %% [markdown]
# ### Core 1: pH classifier
#
# In a chemistry practical you test solutions with a pH probe. Ask for a pH reading and print what it tells you:
#
# | pH | Label |
# | --- | --- |
# | below 3 | Strong acid |
# | below 7 | Weak acid |
# | exactly 7 | Neutral |
# | 11 or below | Weak alkali |
# | above 11 | Strong alkali |
#
# ```text
# Enter the pH reading: 2.5
# pH 2.5: Strong acid
# ```
#
# Test the edges too: `3`, `7`, `11` and `11.5`.

# %%
# Hint 1 for Core 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 1: your code here

# %% [markdown]
# ### Core 2: Radioactive decay
#
# A sample in the physics lab gives **1600** counts per minute. Its half-life is **6 hours**, so every 6 hours the count halves. It is safe to store once it drops **below 50**.
#
# Use a `while` loop to print the count every 6 hours until it is below 50, then say how long that took.
#
# ```text
# 0 hours: 1600.0 counts per minute
# 6 hours: 800.0 counts per minute
# 12 hours: 400.0 counts per minute
# 18 hours: 200.0 counts per minute
# 24 hours: 100.0 counts per minute
# 30 hours: 50.0 counts per minute
# 36 hours: 25.0 counts per minute
# Safe to store after 36 hours
# ```

# %%
# Hint 1 for Core 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 2: your code here

# %% [markdown]
# ### Core 3 (extension): Sports day sprint speeds
#
# The 100 m times from a sports day heat are in the cell. For each runner, work out their average speed (`speed = distance / time`) and print it to two decimal places. Then print who was fastest.
#
# ```text
# Ada: 7.81 m/s
# Ben: 7.46 m/s
# Cy: 8.26 m/s
# Dev: 7.14 m/s
# Fastest: Cy at 8.26 m/s
# ```

# %%
# Hint 1 for Core 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
runners = ["Ada", "Ben", "Cy", "Dev"]
times = [12.8, 13.4, 12.1, 14.0]

# Core 3: your code below this line

# %% [markdown]
# ## Fast Track
#
# At GCSE you traced linear and binary search on paper. Today you write them, count how much work they do, then turn binary search into a way of calculating square roots.
#
# Each search function returns **two** values: the position found (`-1` if missing) and the number of comparisons made:
#
# ```python
# def smallest_and_largest(numbers):
#     """Return the smallest and largest value in numbers."""
#     return min(numbers), max(numbers)
#
#
# low, high = smallest_and_largest([6.8, 24.0, 13.2])
# ```

# %% [markdown]
# ### Fast Track 1: Linear search
#
# Write `linear_search(items, target)`, checking each item in turn from the start. Count one comparison each time you check an item.
#
# | Call | Returns |
# | --- | --- |
# | `linear_search(tmax_2025, 24.0)` | `(5, 6)` |
# | `linear_search(tmax_2025, 30.0)` | `(-1, 12)` |

# %%
# Hint 1 for Fast Track 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("Y29tcGFyaXNvbnMgPC0gMApmb3IgcG9zaXRpb24gaW4gcmFuZ2UobGVuKGl0ZW1zKSk6CiAgICBhZGQgMSB0byBjb21wYXJpc29ucwogICAgaWYgaXRlbXNbcG9zaXRpb25dID09IHRhcmdldDoKICAgICAgICByZXR1cm4gcG9zaXRpb24sIGNvbXBhcmlzb25zCnJldHVybiAtMSwgY29tcGFyaXNvbnM=").decode())

# %%
tmax_2025 = [6.8, 8.4, 13.2, 17.3, 19.6, 24.0, 25.3, 24.2, 19.2, 14.6, 12.0, 9.6]

# Fast Track 1: your function and tests below this line

# %% [markdown]
# ### Fast Track 2: Binary search
#
# Write `binary_search(items, target)` for a **sorted** list. Check the middle item; keep the half the target must be in; repeat.
#
# | Call | Returns |
# | --- | --- |
# | `binary_search(sorted_temps, 24.0)` | `(9, 4)` |
# | `binary_search(sorted_temps, 30.0)` | `(-1, 4)` |
#
# Then search `list(range(100_000))` for `100_000` with both functions. Linear needs 100,000 comparisons. How many does binary need?

# %%
# Hint 1 for Fast Track 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
sorted_temps = sorted(tmax_2025)

# Fast Track 2: your function and tests below this line

# %% [markdown]
# ### Fast Track 3 (extension): Square roots by bisection
#
# Binary search works on numbers too. To find √2: it must lie between 0 and 2. Try the middle, 1. Its square is too small, so the answer is in the upper half. Keep halving the gap until it is tiny.
#
# This is the **bisection method**. Engineers use it to solve equations that have no neat formula.
#
# Write `square_root(n)` that returns the estimate and the number of halvings, stopping when the gap between `low` and `high` is under `0.0001`. Compare with `math.sqrt`.
#
# | Call | Returns, rounded |
# | --- | --- |
# | `square_root(2)` | `(1.4142, 15)` |
# | `square_root(1000)` | `(31.6228, 24)` |

# %%
# Hint 1 for Fast Track 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Fast Track 3: your code here

# %% [markdown]
# ## Before you finish
#
# **Plenary, both lanes:** both lanes halved something today. Core halved a count of radiation, Fast Track halved a search. Why does halving get small so fast, and how many halvings take 1600 below 50?
#
# **Exit ticket.** In the cell below: when would you use `while` instead of `for`? One sentence.
#
# Then save, and commit and sync.

# %%
# Exit ticket

# %% [markdown]
# ## Model solutions
#
# Run the cell and type the passphrase your teacher gives you. Compare, do not copy.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

xme4mRf2RHqZ
"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
