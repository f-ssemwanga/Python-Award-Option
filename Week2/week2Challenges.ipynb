# %% [markdown]
# ### Week 2 Challenges
#
# Do **your lane only**. The placement check told you which one, and it may differ from last week.
#
# - Three challenges each. Number 3 is the **extension**: do it if you finish 1 and 2.
# - Stuck? Run the **hint cell** under the challenge. Have a proper go first.
# - Model solutions are locked at the bottom until after the lesson.

# %% [markdown]
# ## Core

# %% [markdown]
# ### Core 1: Rainfall labeller
#
# Ask for a month's rainfall in mm and print a label: under 20 is **Dry**, under 80 is **Normal**, under 150 is **Wet**, anything else is **Very wet**.
#
# ```text
# Enter the month's rainfall in mm: 124.2
# 124.2 mm is Wet
# ```
#
# Test the edges too: `20`, `80` and `150`.

# %%
# Hint 1 for Core 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 1: your code here

# %% [markdown]
# ### Core 2: Guess the number
#
# The computer picks a number from 1 to 100. The user guesses until they get it. Say `Too high` or `Too low` after each wrong guess, and how many guesses it took at the end.
#
# ```text
# Guess my number, 1 to 100: 50
# Too high
# Guess my number, 1 to 100: 25
# Too low
# Guess my number, 1 to 100: 37
# Got it in 3 guesses
# ```
#
# Play a few times. What is the best way to guess? Keep your answer for the plenary.

# %%
# Hint 1 for Core 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
import random
secret = random.randint(1, 100)

# Core 2: your code below this line

# %% [markdown]
# ### Core 3 (extension): Frosty months
#
# Using the lists in the cell, print each month of 2025 that had at least one frost, then the number of months and the total frost days.
#
# ```text
# January: 12 frost days
# February: 4 frost days
# March: 8 frost days
# November: 6 frost days
# December: 2 frost days
# 5 months had frost, 32 frost days in total
# ```

# %%
# Hint 1 for Core 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
months = ["January", "February", "March", "April", "May", "June",
          "July", "August", "September", "October", "November", "December"]
frost_days = [12, 4, 8, 0, 0, 0, 0, 0, 0, 0, 6, 2]

# Core 3: your code below this line

# %% [markdown]
# ## Fast Track
#
# At GCSE you traced linear and binary search on paper. Today you write them and measure how much work each does.
#
# Each function returns **two** values: the position found (`-1` if missing) and the number of comparisons made. Count one comparison every time you check an item against the target.
#
# ```python
# def smallest_and_largest(numbers):
#     """Return the smallest and largest value in numbers."""
#     return min(numbers), max(numbers)
#
#
# low, high = smallest_and_largest([6.8, 24.0, 13.2])
# ```

# %% [markdown]
# ### Fast Track 1: Linear search
#
# Write `linear_search(items, target)`, checking each item in turn from the start.
#
# | Call | Returns |
# | --- | --- |
# | `linear_search(tmax_2025, 24.0)` | `(5, 6)` |
# | `linear_search(tmax_2025, 30.0)` | `(-1, 12)` |

# %%
# Hint 1 for Fast Track 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
tmax_2025 = [6.8, 8.4, 13.2, 17.3, 19.6, 24.0, 25.3, 24.2, 19.2, 14.6, 12.0, 9.6]

# Fast Track 1: your function and tests below this line

# %% [markdown]
# ### Fast Track 2: Binary search
#
# Write `binary_search(items, target)` for a **sorted** list. Check the middle item. If the target is bigger, keep the upper half; if smaller, the lower half. Repeat.
#
# | Call | Returns |
# | --- | --- |
# | `binary_search(sorted_temps, 24.0)` | `(9, 4)` |
# | `binary_search(sorted_temps, 30.0)` | `(-1, 4)` |

# %%
# Hint 1 for Fast Track 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
sorted_temps = sorted(tmax_2025)

# Fast Track 2: your function and tests below this line

# %% [markdown]
# ### Fast Track 3 (extension): Measure it
#
# **Guess first:** how many comparisons does each search need to find that a number is **not** in a list of 10, 1,000 and 100,000 items?
#
# Then check. For each size, make `numbers = list(range(size))`, search it for `size` (never in the list), and print both counts:
#
# ```text
#      10 items: linear      10, binary   4
# ```
#
# In the markdown cell below, explain in two sentences why binary search barely notices the list getting 10,000 times longer.

# %%
# Hint 1 for Fast Track 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
# Fast Track 3: your code here

# %% [markdown]
# *Fast Track 3: your explanation here. Double click to edit.*

# %% [markdown]
# ## Before you finish
#
# **Plenary, both lanes:** what is the best way to play Guess the Number from 1 to 100, and what is the most guesses it can ever need?
#
# **Exit ticket.** In the cell below: when would you use `while` instead of `for`? One sentence.
#
# Then save, and commit and sync.

# %%
# Exit ticket

# %% [markdown]
# ## Model solutions
#
# Run the cell and type the passphrase your teacher gives you. Compare, do not copy.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

J6E7j4qklULEkz9krmo5WOsqKlQtc9L7BZz5
"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
