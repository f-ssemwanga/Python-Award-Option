# %% [markdown]
# ### Week 3 Challenges
#
# Do **your lane only**. The placement check told you which one.
#
# - Three challenges each. Number 3 is the **extension**: do it if you finish 1 and 2.
# - Stuck? Run the **hint cell** under the challenge. Have a proper go first.
# - Model solutions are locked at the bottom until after the lesson.

# %% [markdown]
# ## Core

# %% [markdown]
# ### Core 1: Percentage error
#
# In a physics practical you measured g, the acceleration due to gravity, as **9.6 m/s²**. The accepted value is **9.81 m/s²**. How far out were you?
#
# Write a function `percentage_error(measured, accepted)` that **returns** the percentage error:
#
# `percentage error = (measured - accepted) / accepted * 100`, ignoring the sign.
#
# ```text
# Measured 9.6, accepted 9.81: 2.1% error
# ```

# %%
# Hint 1 for Core 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 1: your code here

# %% [markdown]
# ### Core 2: Kinetic energy
#
# Write `kinetic_energy(mass, speed)` that **returns** the kinetic energy in joules: `KE = 0.5 × mass × speed²`.
#
# Use it to compare a rugby player running at full pace with a cricket ball from a fast bowler:
#
# ```text
# Rugby player (85 kg at 7.5 m/s): 2390.6 J
# Cricket ball (0.16 kg at 35 m/s): 98.0 J
# ```
#
# The ball is going almost five times faster, so why does the player have far more energy?

# %%
# Hint 1 for Core 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 2: your code here

# %% [markdown]
# ### Core 3 (extension): Is the dice fair?
#
# Probability says a fair dice lands on 6 one time in six. Test it by experiment.
#
# Write `count_sixes(rolls)` that rolls a dice `rolls` times using `random.randint(1, 6)` and **returns** how many sixes came up. Run it for 60, 600 and 60,000 rolls and compare each with the expected number.
#
# ```text
# 60 rolls: 8 sixes, expected 10
# 600 rolls: 93 sixes, expected 100
# 60000 rolls: 10046 sixes, expected 10000
# ```
#
# Your numbers will differ each time. What happens to the gap between result and expectation, as a percentage, as the experiment gets bigger?

# %%
# Hint 1 for Core 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Core 3: your code here

# %% [markdown]
# ## Fast Track
#
# You wrote subroutines at GCSE. Today: **default arguments**, writing **your own module** in a `.py` file, and **repeatable** random experiments.

# %% [markdown]
# ### Fast Track 1: Default arguments
#
# A parameter can have a default value, used when the caller leaves it out.
#
# Write `projectile_range(speed, angle=45, g=9.81)` that returns how far a projectile travels on level ground:
#
# `range = speed² × sin(2 × angle) / g`
#
# Angles in Python's `math` module are in radians, so convert with `math.radians(...)` first.
#
# | Call | Returns, rounded |
# | --- | --- |
# | `projectile_range(20)` | `40.77` |
# | `projectile_range(20, 30)` | `35.31` |
# | `projectile_range(20, g=1.62)` | `246.91`, the same throw on the Moon |

# %%
# Hint 1 for Fast Track 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Fast Track 1: your code here

# %% [markdown]
# ### Fast Track 2: Your own physics module
#
# Run the first cell below as it is. `%%writefile` saves the rest of the cell as a real Python file, `physics.py`. The second cell then imports it like any other module.
#
# Add a second function to the file, `weight(mass, g=9.81)`, returning weight in newtons. Run the file cell again, then use it from the import cell:
#
# | Call | Returns |
# | --- | --- |
# | `physics.kinetic_energy(85, 7.5)` | `2390.625` |
# | `physics.weight(85)` | `833.85` |
# | `physics.weight(85, g=1.62)` | the same person on the Moon |
#
# You never copy the functions into the notebook. That is the point of a module: write once, import anywhere. Scientists build up modules like this over years.

# %%
# Hint 1 for Fast Track 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# %%writefile physics.py
"""Physics formulas, all in SI units."""


def kinetic_energy(mass, speed):
    """Return kinetic energy in joules, for mass in kg and speed in m/s."""
    return 0.5 * mass * speed ** 2

# %%
import importlib
import physics
importlib.reload(physics)

print(physics.kinetic_energy(85, 7.5))
# Fast Track 2: test weight here

# %% [markdown]
# ### Fast Track 3 (extension): Estimating π with random numbers
#
# Throw random darts at a 1 by 1 square. The fraction landing inside the quarter circle of radius 1 is π/4. So π ≈ 4 × (hits ÷ throws). This is a **Monte Carlo** method, used across physics and engineering.
#
# Write `estimate_pi(throws, seed=None)`. With the same seed it must give the same answer every time, so another scientist can check your result.
#
# Try 1,000, 100,000 and 1,000,000 throws. Twice with `seed=2026` should match exactly.

# %%
# Hint 1 for Fast Track 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("...").decode())

# %%
# Fast Track 3: your code here

# %% [markdown]
# ## Before you finish
#
# **Plenary, both lanes:** what is the difference between a function that **prints** its answer and one that **returns** it? Why could Core 2 and Fast Track 2 not work with a function that only prints?
#
# **Exit ticket.** In the cell below, write a function `density(mass, volume)` that returns mass divided by volume, and print `density(540, 200)`.
#
# Then save, and commit and sync.

# %%
# Exit ticket

# %% [markdown]
# ## Model solutions
#
# Run the cell and type the passphrase your teacher gives you. Compare, do not copy.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

Ugoux4fQ+d38YmVmBDyq19UnIzxs
"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
