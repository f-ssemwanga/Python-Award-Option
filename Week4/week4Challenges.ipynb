# %% [markdown]
# ### Week 4 Challenges
#
# Do **your lane only**. The placement check told you which one.
#
# - Three challenges each. Number 3 is the **extension**: do it if you finish 1 and 2.
# - Stuck? Run the **hint cell** under the challenge. Have a proper go first.
# - Model solutions are locked at the bottom until after the lesson.

# %% [markdown]
# ## Core

# %% [markdown]
# ### Core 1: Practical kit list
#
# Before a chemistry practical you check the equipment list in the cell. Add `"thermometer"` and `"stopwatch"`, remove `"bunsen burner"` (this practical uses a water bath), then print the list in alphabetical order with numbers, followed by how many items there are.
#
# ```text
# 1. beaker
# 2. measuring cylinder
# 3. stopwatch
# 4. thermometer
# 5. water bath
# Items: 5
# ```

# %%
# Hint 1 for Core 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
kit = ["beaker", "bunsen burner", "measuring cylinder", "water bath"]

# Core 1: your code below this line

# %% [markdown]
# ### Core 2: Repeat readings
#
# You timed 10 swings of a pendulum six times. The readings, in seconds, are in the cell. One of them looks wrong.
#
# 1. Print the mean, the range (largest minus smallest) and the uncertainty (half the range), all to two decimal places.
# 2. Spot the anomaly, remove it from the list with `.remove()`, and print all three again.
#
# ```text
# Mean 15.52 s, range 1.80 s, uncertainty 0.90 s
# Removed anomaly: 16.9
# Mean 15.24 s, range 0.30 s, uncertainty 0.15 s
# ```
#
# Removing one bad reading cuts the uncertainty to a sixth. That is why scientists take repeat readings.

# %%
# Hint 1 for Core 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
readings = [15.2, 15.4, 15.1, 16.9, 15.3, 15.2]

# Core 2: your code below this line

# %% [markdown]
# ### Core 3 (extension): Measuring g with a pendulum
#
# Each tuple in the cell is `(length in m, period in s)` from a pendulum experiment. For each one, work out g using `g = 4π²L / T²`, print a table, then print the mean.
#
# ```text
# L = 0.20 m, T = 0.90 s, g = 9.75
# L = 0.40 m, T = 1.27 s, g = 9.79
# L = 0.60 m, T = 1.55 s, g = 9.86
# L = 0.80 m, T = 1.80 s, g = 9.75
# L = 1.00 m, T = 2.01 s, g = 9.77
# Mean g = 9.78 m/s²
# ```

# %%
# Hint 1 for Core 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
results = [(0.20, 0.90), (0.40, 1.27), (0.60, 1.55), (0.80, 1.80), (1.00, 2.01)]

# Core 3: your code below this line

# %% [markdown]
# ## Fast Track
#
# You used lists and 2D lists at GCSE. Today: **dictionaries**, and two structures built from lists, the **stack** and the **queue**.

# %% [markdown]
# ### Fast Track 1: Molar mass calculator
#
# A dictionary stores **key: value** pairs, looked up by key rather than position. The cell holds relative atomic masses.
#
# A formula is given as a dictionary of element counts, so water, H₂O, is `{"H": 2, "O": 1}`. Write `molar_mass(formula)` that returns the molar mass to two decimal places.
#
# | Call | Returns |
# | --- | --- |
# | `molar_mass({"H": 2, "O": 1})` | `18.02` |
# | `molar_mass({"C": 1, "O": 2})` | `44.01` |
# | `molar_mass({"C": 6, "H": 12, "O": 6})` | `180.16`, glucose |

# %%
# Hint 1 for Fast Track 1. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
ATOMIC_MASS = {"H": 1.008, "C": 12.011, "N": 14.007, "O": 15.999,
               "Na": 22.990, "Cl": 35.45, "Ca": 40.078}

# Fast Track 1: your code below this line

# %% [markdown]
# ### Fast Track 2: A stack that checks brackets
#
# A **stack** is last in, first out. In Python a list does it: `append` pushes on to the top, `pop()` takes off the top.
#
# Chemical formulas and equations both nest brackets, and so does code. Write `balanced(text)` that returns `True` if every `(`, `[` and `{` is closed by the right partner in the right order.
#
# | Call | Returns |
# | --- | --- |
# | `balanced("Ca(OH)2")` | `True` |
# | `balanced("[Cu(NH3)4]SO4")` | `True` |
# | `balanced("[Cu(NH3]4)SO4")` | `False` |
# | `balanced("((a+b)*c")` | `False` |

# %%
# Hint 1 for Fast Track 2. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
# Fast Track 2: your code here

# %% [markdown]
# ### Fast Track 3 (extension): The lunch queue
#
# A **queue** is first in, first out. Taking from the front of a list with `pop(0)` gets slow on long lists, so Python has `collections.deque`, built for it: `append` joins the back, `popleft()` serves the front.
#
# Process the events in the cell. `join` adds a name to the queue, `serve` serves whoever is at the front. Print who is served, then who is still waiting.
#
# ```text
# Served: Ada
# Served: Ben
# Served: Cy
# Still waiting: ['Dev', 'Eve']
# ```

# %%
# Hint 1 for Fast Track 3. Run this cell only if you are stuck.
import base64; print(base64.b64decode("").decode())

# %%
events = ["join Ada", "join Ben", "serve", "join Cy", "serve",
          "join Dev", "serve", "join Eve"]

# Fast Track 3: your code below this line

# %% [markdown]
# ## Before you finish
#
# **Plenary, both lanes:** when would you use a list, and when something else? Core: list or tuple, and why were the pendulum results tuples? Fast Track: list, dictionary, stack or queue.
#
# **Exit ticket.** In the cell below, make a list of three repeat readings, add a fourth, and print their mean.
#
# Then save, and commit and sync.

# %%
# Exit ticket

# %% [markdown]
# ## Model solutions
#
# Run the cell and type the passphrase your teacher gives you. Compare, do not copy.

# %%
# Model solutions. Run this cell and enter the passphrase when asked.
# Without the right passphrase the text below cannot be turned back into the answers.

import base64, getpass, hashlib, hmac, zlib
from IPython.display import Markdown, display

LOCKED = """

BCzD/mBF
"""


def unlock(blob, passphrase):
    data = base64.b64decode(blob)
    salt, tag, body = data[:16], data[16:48], data[48:]
    phrase = " ".join(passphrase.lower().split()).encode()
    key = hashlib.pbkdf2_hmac("sha256", phrase, salt, 300_000, dklen=64)
    if not hmac.compare_digest(tag, hmac.new(key[32:], salt + body, "sha256").digest()):
        return None
    stream = b"".join(hashlib.sha256(key[:32] + i.to_bytes(8, "big")).digest()
                      for i in range(len(body) // 32 + 1))
    return zlib.decompress(bytes(a ^ b for a, b in zip(body, stream))).decode()


solutions = unlock(LOCKED, getpass.getpass("Passphrase: "))
if solutions is None:
    print("That is not the passphrase. Nothing has been revealed.")
else:
    display(Markdown(solutions))
